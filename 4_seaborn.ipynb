# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
crash_df = sns.load_dataset('car_crashes')
crash_df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
#Distribution Plot
sns.distplot(crash_df['not_distracted'])
# Out:
# /data/user/0/ru.iiec.pydroid3/cache/ipykernel_15260/886231449.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(crash_df['not_distracted'])
# <Axes: xlabel='not_distracted', ylabel='Density'>

# %%
#Distribution Plot
sns.distplot(crash_df['not_distracted'],kde= False)
# Out:
# /data/user/0/ru.iiec.pydroid3/cache/ipykernel_15260/441926134.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(crash_df['not_distracted'],kde= False)
# <Axes: xlabel='not_distracted'>

# %%
#Distribution Plot
sns.distplot(crash_df['not_distracted'],kde= False, bins= 25)
# Out:
# /data/user/0/ru.iiec.pydroid3/cache/ipykernel_15260/2874621504.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(crash_df['not_distracted'],kde= False, bins= 25)
# <Axes: xlabel='not_distracted'>

# %%
#Joint plot
sns.jointplot(x='speeding',y='alcohol', data= crash_df, kind = 'reg')

# %%
sns.jointplot(x='speeding',y='alcohol', data= crash_df, kind = 'kde')

# %%
sns.jointplot(x='speeding',y='alcohol', data= crash_df, kind = 'hex')

# %%
#KDE plot
sns.kdeplot(crash_df['alcohol'])
plt.show()

# %%
#Pair Plot
sns.pairplot(crash_df)

# %%
tips_df= sns.load_dataset('tips')
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips_df= sns.load_dataset('tips')
# hue :- On what basis will the distribution be done? 
#palette :- color of plots
sns.pairplot(tips_df, hue= 'sex', palette='Blues')

# %%
#Rug Plot
sns.rugplot(tips_df['tip'])
# Out:
# <Axes: xlabel='tip'>

# %%
#styling
sns.set_style('white')

sns.jointplot(x='speeding', y= 'alcohol', data= crash_df, kind = 'reg')

# %%
#styling
sns.set_style('white')
plt.figure(figsize=(8,4))
sns.jointplot(x='speeding', y= 'alcohol', data= crash_df, kind = 'reg')

# %%
#styling
sns.set_style('darkgrid')#whitegrid, dark, ticks,
plt.figure(figsize=(8,4))
sns.jointplot(x='speeding', y= 'alcohol', data= crash_df, kind = 'reg')

# %%
#styling
sns.set_style('darkgrid')
plt.figure(figsize=(8,4))
sns.set_context('paper', font_scale=1.4) #Font size change 
sns.jointplot(x='speeding', y= 'alcohol', data= crash_df, kind = 'reg')

# %%
#styling
sns.set_style('darkgrid')
plt.figure(figsize=(8,4))
sns.set_context('talk', font_scale=1.4) #Font size change 
sns.jointplot(x='speeding', y= 'alcohol', data= crash_df, kind = 'reg')

# %%
#styling
sns.set_style('darkgrid')
plt.figure(figsize=(8,4))
sns.set_context('poster', font_scale=1.4) #Font size change 
sns.jointplot(x='speeding', y= 'alcohol', data= crash_df, kind = 'reg')
# Out:
# /data/user/0/ru.iiec.pydroid3/files/arm-linux-androideabi/lib/python3.11/site-packages/seaborn/axisgrid.py:1766: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   f.tight_layout()

# %%
#Desp Plot
sns.set_context('paper', font_scale=1.4)
sns.jointplot(x='speeding', y= 'alcohol', data= crash_df, kind = 'reg')

sns.despine(left= True, bottom = True) #Left and bottom line is disable

# %% [markdown]
# **Categorial plots**

# %%
#Bar plot
sns.barplot(x='sex' , y= 'total_bill', data = tips_df)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
#Bar plot
sns.barplot(x='sex' , y= 'total_bill', data = tips_df,estimator= np.median)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
#Bar plot
sns.barplot(x='sex' , y= 'total_bill', data = tips_df,estimator= np.var)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
#Bar plot
sns.barplot(x='sex' , y= 'total_bill', data = tips_df,estimator= np.std)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
#Bar plot
sns.barplot(x='sex' , y= 'total_bill', data = tips_df,estimator= np.cov)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
#Count plot
sns.countplot(x='sex' , data = tips_df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
#Box Plot
sns.boxplot(x='day', y= 'total_bill',data=tips_df , hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#Box Plot
sns.boxplot(x='day', y= 'total_bill',data=tips_df , hue='sex')
plt.legend(loc= 0)

# %%
#Violin plot
sns.violinplot(x='day',y= 'total_bill', data=tips_df, hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#Violin plot
sns.violinplot(x='day',y= 'total_bill', data=tips_df, hue='sex', split= True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#strip plot
plt.figure(figsize=(8,5))

sns.stripplot(x='day' , y= 'total_bill', data= tips_df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#strip plot
plt.figure(figsize=(8,5))

sns.stripplot(x='day' , y= 'total_bill', data= tips_df, jitter= True , hue ='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#strip plot
plt.figure(figsize=(8,5))

sns.stripplot(x='day' , y= 'total_bill', data= tips_df, jitter= True , hue ='sex', dodge= True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#Swarm plot
sns.swarmplot(x='day',y='total_bill', data= tips_df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#Palettes
plt.figure(figure=(8,5))
sns.set_style('dark')
sns.set_context('talk')
sns.stripplot(x='day', y='total_bill', data = tips_df, hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#Going to matplotlib color map.. in google

# %%
#Palettes
plt.figure(figure=(8,5))
sns.set_style('dark')
sns.set_context('talk')
sns.stripplot(x='day', y='total_bill', data = tips_df, hue='sex', palette= 'magma')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#Palettes
plt.figure(figure=(8,5)) #you can change figure size 
sns.set_style('dark')
sns.set_context('talk')
sns.stripplot(x='day', y='total_bill', data = tips_df, hue='sex', palette= 'magma')
plt.legend(loc=2) #location = 0(upper left ), 1(upper right), 2(lower left), 3(lower right)

# %%
#Going to matplotlib website for more palette..

# %%
#Matrix Plot..
# Heatmaps
plt.figure(figsize=(8,6))
sns.set_context('paper', font_scale=1.4)

crash_df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
# Check the columns of your DataFrame before removing the column
print("Before removing column:")
print(crash_df.head())

# Remove the "abbrev" column from the DataFrame
crash_df = crash_df.drop(columns=['abbrev'])

# Check the columns of your DataFrame after removing the column
print("\nAfter removing column:")
print(crash_df.head())
# Out:
# Before removing column:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA
#
# After removing column:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# ...

# %%
#Matrix Plot..
# Heatmaps
plt.figure(figsize=(8,6))
sns.set_context('paper', font_scale=1.4)

crash_mx= crash_df.corr()
sns.heatmap(crash_mx, annot=True, cmap='Blues')
# Out:
# <Axes: >

# %%
flights = sns.load_dataset('flights')
flights = flights.pivot_table(index='month', columns= 'year', values= 'passengers')
sns.heatmap(flights, cmap='Blues', linecolor ='white')
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
flights = sns.load_dataset('flights')
flights = flights.pivot_table(index='month', columns= 'year', values= 'passengers')
sns.heatmap(flights, cmap='Blues', linecolor ='white',linewidth = 1)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
#Cluster maps
#install 'scipy'
iris= sns.load_dataset('iris')
species= iris.pop('species')
sns.clustermap(iris)

# %%
#Cluster maps
#iris= sns.load_dataset('iris')
#species= iris.pop('species')
#sns.clustermap(iris)
sns.clustermap(flights, cmap= 'Blues', standard_scale=1)

# %%
#Pair Grid 
iris=sns.load_dataset('iris')
iris_g = sns.PairGrid(iris, hue= 'species')
iris_g.map(plt.scatter)
#it is based on scatter plot

# %%
#Pair Grid 
iris=sns.load_dataset('iris')
iris_g = sns.PairGrid(iris, hue= 'species')
iris_g.map(plt.scatter)
iris_g.map_diag(plt.hist)
#plot histogram

# %%
#Pair Grid 
iris=sns.load_dataset('iris')
iris_g = sns.PairGrid(iris, hue= 'species')
iris_g.map_diag(plt.hist)
iris_g.map_offdiag(plt.scatter)

# %%
#Pair Grid 
iris=sns.load_dataset('iris')
iris_g = sns.PairGrid(iris, hue= 'species')
iris_g.map_diag(plt.hist)
iris_g.map_upper(plt.scatter)#upper part "scatter plot"
iris_g.map_lower(sns.kdeplot)#lower part "kde plot"

# %%
#Pair Grid 
iris=sns.load_dataset('iris')
iris_g = sns.PairGrid(iris, hue= 'species')
iris_g.map_diag(plt.hist)
iris_g.map_upper(plt.scatter)#upper part "scatter plot"
iris_g.map_lower(sns.kdeplot)#lower part "kde plot"
iris_g = sns.PairGrid(iris, hue= "species",
                      x_vars= ["sepal_length", "sepal_width"],
                      y_vars= ["petal_length", "petal_width"])
iris_g.map(plt.scatter)
iris_g.add_legend()

# %%
#Facet Grid
tips_fg = sns.FacetGrid(tips_df, col= 'time', hue= 'smoker')
tips_fg.map(plt.hist, 'total_bill', bins= 8) #attributes
#you can include "Scatter" or any other plot in the place of "hist"

# %%
#Facet Grid
tips_fg = sns.FacetGrid(tips_df, col= 'time', hue= 'smoker')
tips_fg.map(plt.scatter, 'total_bill', 'tip') #attributes with scatter plot

# %%
#Facet Grid
tips_fg = sns.FacetGrid(tips_df, col= 'time', hue= 'smoker', height = 4, aspect=1.3,
                       col_order=[ 'Dinner', 'Launch'] , palette='Set1')
#assign a variable with different color
tips_fg.map(plt.scatter, 'total_bill','tip', edgecolor='w')

# %%
att_df= sns.load_dataset('attention')
att_fg = sns.FacetGrid(att_df, col= 'subject', col_wrap=5 , height=1.5)
att_fg.map(plt.plot, 'solutions', 'score', marker= 'o')

# %%
#Regression Plot
plt.figure(figsize=(8,6))
sns.set_context('paper', font_scale=1.4)
sns.lmplot(x='total_bill', y='tip', hue = 'sex', data= tips_df, markers= ['o', '^'],
           scatter_kws= {'s': 100, 'linewidths': 0.5, 'edgecolor':'w'})

# %%
sns.lmplot(x= 'total_bill',y= 'tip', col='sex',row='time' , data= tips_df)

# %%
sns.set_context('paper', font_scale= 1.4)
sns.lmplot(x= 'total_bill',y= 'tip', col='sex',row='time' , data= tips_df)

# %%
sns.set_context('paper', font_scale= 1.4)
sns.lmplot(x= 'total_bill',y= 'tip', col='sex',row='time' , data= tips_df,
          height = 8, aspect= 0.6)
