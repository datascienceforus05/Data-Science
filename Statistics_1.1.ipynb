# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sec_a = np.array([75,65,73,68,72,67])
sec_b = np.array([90,47,43,96,93,51])
no = np.array ([1,2,3,4,5,6])

# %% [markdown]
# **USING STANDARD DIVISION**

# %%
np.std(sec_a), np.std(sec_b)
# Out:
# (3.559026084010437, 23.18045153428495)

# %% [markdown]
# **USING VARIANCE**

# %%
np.var(sec_a), np.var(sec_b)
# Out:
# (12.666666666666666, 537.3333333333334)

# %% [markdown]
# This means Variance is a square of Standard Division..Both are same !! [(std)² = var] { Low *std* and *var* are used }

# %%
3.559026084010437**2 #Both are same
# Out:
# 12.666666666666666

# %%
path = "/content/drive/MyDrive/Excel-and-CSV-files/titanic.csv"
df = pd.read_csv(path)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Age'].var()
# Out:
# 211.01912474630802

# %% [markdown]
# This data is very spread...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.histplot(x = "Age", data = df)
plt.show()

# %%
df["Age"].std()
# Out:
# 14.526497332334042

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# 25% , 50% , 75% are not a percentage it's percentile ...

# %%
# Percentage And Percentile difference

# %% [markdown]
# **Percentage And Percentiles are Very Different**
#
# Percentage:- Individual value of a data..
#
# Percentile:- Position in Group of data.. ( Used for find the base )

# %% [markdown]
# **Percentile :- Percentiles are used to give you a number that describes the value that a given percent of the values are lower than.**
#
#
# **Quartile :- when we brake the percentile into 4 parts ( 25% 50% 75% 100% .. Then this is called Quartiles..)**
#
#
# *This is used in **Interquartile Range** (IQR)*

# %% [markdown]
# *IQR method is used when we work in ML.. We have some amount of outlier ( Beyond of range ) .. To find these Outliers we use IQR method*

# %% [markdown]
# **IQR = Q3 - Q1** (See Copy)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df["Age"].fillna(df["Age"].mean(), inplace = True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
np.percentile(df["Age"] ,25) #25% percentile of Age
# Out:
# 22.0

# %%
np.percentile(df["Age"] ,50), np.percentile(df["Age"] ,75)
# Out:
# (29.69911764705882, 35.0)

# %%
np.percentile(df["Age"] ,0)
# Out:
# 0.42

# %%
df["Age"].min()
# Out:
# 0.42

# %%
df["Age"].max()
# Out:
# 80.0

# %%
df["Age"].median() #Middle value :- Same as 50% percentile
# Out:
# 29.69911764705882

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   13.002015    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   29.699118    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# This data have outlier because 0.42 is minimum, 22 is 25% , 29% median, 35 is 75% , and last 80 is 100% .. **There is Outliers between 75% and 100% because there is a very gap**

# %%
#We are using box plot for see that outliers in Age column

sns.boxplot( x = "Age", data = df)
plt.show()

# %% [markdown]
# **See That Outlines point**

# %%
sns.boxplot( x = "Fare", data = df)
plt.show() # In Fare Column

# %% [markdown]
# TIME STAMP :- 1.39.00

# %% [markdown]
# **Measure Of Shape**

# %% [markdown]
# *SKEWNESS* :- Skewness measures the asymmetry of the distribution
#
# To see the Skewness we use ---
# **FREQUENCY AND CUMULATIVE DISTRIBUTION**
#
# FREQUENCY DISTRIBUTION:- A Frequency distribution is a table that shows the number of occurrence of difference values in a dataset.
#
# CUMULATIVE DISTRIBUTION:- A Cumulative Distribution shows the accumulation of frequencies up to a certain point.It is obtained by adding up the frequencies as you move through the values.

# %% [markdown]
# *There are three types of Skewness charts*
#
# a. Negatively Skewness :- Tail is in the left side and head in right side. (Outliers are available) *Mean<Median<Mode*
#
# b. Normal (no skew):- There are no Skewness.. left and right sides are equal. (Outliers are not available)
# *Equal*
#
# c. Positive Skewness :- Head is in the left side and Tail in right side. (Outliers are available)
# *Mean>Median>Mode*

# %%
sns.histplot(x="Age", data = df)
plt.show() #Positive Skewness

# %%
df["Age"].skew()
# Out:
# 0.4344880940129925

# %%
df["Age"].mean() ,df["Age"].median(), df["Age"].mode()[0]
# Out:
# (29.69911764705882, 29.69911764705882, 29.69911764705882)

# %% [markdown]
# **Probability**
#
# -Random Variable :- It is a function, sample collection of data.
#
# *Two types of **Random Variables** --*
#
# •Discrete Random Variable :- A Random Variable that takes on a countable number of distinct values. (e.g. Dice, Coin sides )
#
# •Continuous Random Variable:- A Random Variable that can take on any value within a given range or interval. (e.g. People heights and age)
#
# **PROBABILITY**:- Probability measures the likelihood of a particular outcome or event occuring. It is typically expressed as a number between 0 and 1, where / indicates impossibility (event will not occur) and 1 indicates certainty (event will occur).
#
# *Formula*:-
#
# P(A) = Number of times A occurs/ Total number of possible outcomes

# %% [markdown]
# *Probability Distribution* :- Probability Distribution describe how the probabilities of different outcomes are distributed over the sample space of a random variable.
#
# • Discrete Probability Distribution.
#
# • Continuous Probability Distribution.

# %% [markdown]
# *Probability Distribution Function* :- A probability distribution is the mathematical function that gives the probabilities of occurrence of different possible outcomes for an experiment.
#
# *FORMULA*:- p(x) = y
#
# **THERE ARE THREE TYPES OF PROBABILITY DISTRIBUTION FUNCTION**
# 1.PDF (Probability Density Function):- Using in Continuous data.
#
# 2.PMF (Probability Mass Function):- Using in Discrete data.
#
# 3.CDF (Cumulative Density Function) :- Using in Cumulative data( 1+2= 3, 3+4= 7,7+8= 15).
#
#
# **Very popular Distribution** :- NORMAL DISTRIBUTION
#
#
# **NORMAL DISTRIBUTION** :- (see copy)
#
# **STANDARD NORMAL DISTRIBUTION** :- The standard normal distribution, also known as the Z distribution or Z-Score, is a special case of normal distribution. Mean of 0 and a standard deviation of 1.

# %% [markdown]
# 2.32.000
#
# **COVARIANCE AND CORRELATION**
#
# (Relation between two data or column)
#
# *COVARIANCE* :- Linear relationship between two variables.
#
# *Range :- - Infinite to + Infinite*
#
# *CORRELATION* :- Range :- -1 to +1

# %%
path_1 = "/content/drive/MyDrive/Excel-and-CSV-files/tips.csv"
df_1= pd.read_csv(path_1)

# %%
df_1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df_1.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df_1.select_dtypes(["float64","int64"])
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
data_corr = df_1.select_dtypes(["float64","int64"]).corr()
data_corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
data_cov=df_1.select_dtypes(["float64","int64"]).cov()
data_cov
# Out:
#             total_bill       tip      size
# total_bill   79.252939  8.323502  5.065983
# tip           8.323502  1.914455  0.643906
# size          5.065983  0.643906  0.904591

# %%
sns.heatmap(data_corr,annot = True)
plt.show()

# %%
sns.heatmap(data_cov,annot= True)
plt.show()

# %% [markdown]
# **CENTRAL LIMIT THEOREM**(CLT):-
#
# The CLT states that when plotting a sample distribution of means the means of the sample will be equal to the population mean and the sample distribution will approach normal distribution with Variance equal to standard error.

# %%
pop_data = [np.random.randint(10,100)for i in range(10000)] # 10 to 100, 10000 random data

# %%
len(pop_data)
# Out:
# 10000

# %%
pop_table =pd.DataFrame({"pop_data":pop_data})
pop_table
# Out:
#       pop_data
# 0           61
# 1           84
# 2           96
# 3           92
# 4           56
# ...        ...
# 9995        80
# 9996        40
# 9997        12
# 9998        16
# 9999        48
#
# [10000 rows x 1 columns]

# %%
plt.figure(figsize=(3,2))
sns.kdeplot(x="pop_data",data = pop_table)
plt.show()

# %%
#Checking normal Distribution

#picking sample data
sample_mean =[]
for no_sample in range (50):
    sample_data = []
    for data in range (500):
       sample_data.append(np.random.choice(pop_data))
    sample_mean.append(np.mean(sample_data))

# %%
sample_M = pd.DataFrame ({"Sample_Mean":sample_mean})

# %%
sns.kdeplot(x="Sample_Mean",data = sample_M)
plt.show()

# %% [markdown]
# mean of pop data is equal to the mean of sample mean data !!

# %%
np.mean(pop_data)
# Out:
# 54.4922

# %%
np.mean(sample_mean)
# Out:
# 54.17171999999999

# %% [markdown]
# **HYPOTHESIS TESTING** :- It is a part of statistical analysis, where we test the assumptions made regarding a population parameter. It is generally used when we were to compare a single group with an external standard and two or more groups with each other.
#
# **Terminology Used In Hypothesis Testing**
#
# *•Null Hypothesis* : Null Hypothesis is a Statistical theory that suggests there us no Statistical significance exists between the populations. It is denoted by H0 and read as H-naught.
#
# *•Alternative Hypothesis* : An Alternative hypothesis suggests there is a significant difference between the population parameters. It could be greater or smaller. Basically, it is the contrast of the Null Hypothesis. It is denoted by Ha or H1.
#
# *Hypothesis Testing* :-
#
# • Z-Test:- (Data --> In the average (Sample data))
#
# • T-Test:- (Data --> In the average (Sample data))
#
# • Chi-Square Test:- ( Tell Perfect or not , Tell the relation is available or not )
#
# **STEPS OF HYPOTHESIS TESTING**
#
# • State null(H0) and alternative      (H1) hypothesis
#
# • Choose level or significance(a)
#
# • Find critical values
#
# • Find test statistic
#
# • Draw your conclusion
#
# _________________________________
#
# *• State null(H0) and Alternative (H1) hypothesis:*
#
# H0 must always contain equality (=). H1 always contains difference ( ≠ ,> ,<).
#
# *• Choose level or significance(a):*
#
# Denoted by alpha or α. It is a fixed Probability of wrongly rejected a True Null Hypothesis.
# (α value depends on Domain)
#
# *• Find Test Statistics:*
#
# Z-Test :- When we have Mean of Population data, Standard Division and Sample data size > 30, Sample data mean.
#
# T-Test :- When we have Population data mean, Standard division of sample data, sample data size < 30, sample data mean.
#
# Chi-Square Test:- Check Goodness, Relationship between two variables.
#
# *• Find critical values:
#
# Find the value of test ( Z-Test value, T-Test value )
#
# *•Draw your conclusion:*
#
# Then come to a conclusion. ( H0 or H1 is right? )

# %% [markdown]
# **Z-Test** :-
#
# *Hypothesis testing (Z-Test)* --->>>
#
# •Example 1:
#
# A teacher vlaims that the mean score of students in his class is greater than 82 with a standard deviation of 20. If a sample of 81 students was selected with a mean score of 90.
#
# [μ(mean) =82, σ(standard deviation) = 20, n(sample data) = 81, x̄(mean of sample data) = 90]
#
# **Z-Test= x̄-μ/(σ/√n)**
#
# __________________________________
# Find H0 and H1 ---
#
# H0 = μ ≠ 82
#
# H1 = μ > 82
#
# α = 0.05 (see copy)
#
# (Google :- Z score table..  Go to.. https://www.z-table.com/ !! Search 0.95 in table )
#
# See corresponding row(1.6) and column (0.04) and add them ... Add them (1.64)
#
# Z- value = 1.64
#
# Z-calculation (Z-Test formula) = 90-82/(20/√81) = 3.6 (Z-Calculated)
#
# *This is in H1 area, so the teacher is said true (μ > 82)*
#
# **In code** --->>>>

# %%
import scipy.stats as st
st.norm.ppf(0.95) #This is calculate Z-value , without using z- table
# Out:
# 1.6448536269514722

# %%
x = 90
u = 82 #μ
p_std = 20  #σ
n = 81
ap = 0.05 #α

# %%
import numpy as np
z_cal = (x-u)/(p_std/np.sqrt(n))
z_cal #this calculates the Z
# Out:
# 3.5999999999999996

# %%
z_table = st.norm.ppf(1-ap)
z_table
# Out:
# 1.6448536269514722

# %%
if z_table < z_cal :
    print("H1 is right")
else :
    print("H0 is right")
# Out:
# H1 is right

# %% [markdown]
# *EXAMPLE 2*
#
# Scenario : Imagine you work for an e-commerce company, and your team is responsible for analyzing customer purchase data. You want to determine whether a new website design has led to a significant increase in the average purchase amount compared to the old design.
#
# Data : You have collected data from a random sample of 30 customers who made purchases on the old website design and 30 customers who made purchases on the new website design. You have the sample means, sample standard deviations, and sample sizes for both groups.
#
# • Old design data = [45.2, 42.8, 38.9, 43.5, 41.0, 44.6, 40.5, 42.7, 39.8, 41.4, 44.3,39.7, 42.1, 40.6, 43.0, 42.2,41.5, 39.6, 44.0, 43.1, 38.7, 43.9, 42.0, 41.9, 42.8, 43.7, 41.3, 40.9, 42.5, 41.6]
#
# • New design data = [48.5, 49.1, 50.2, 47.8, 48.7, 49.9, 48.0, 50.5, 49.8, 49.6,48.2, 48.9, 49.7, 50.3, 49.4,50.1, 48.6, 48.3, 49.0, 50.0, 48.4, 49.3, 49.5, 48.8, 50.6, 50.4, 48.1, 49.2, 50.7,50.8]
#
# • Population std = 2.5
#
# **_Solve_** -->>>
#
# H0 => New = Old,
# H1 => New > Old
#
# μ(New) = μ(Old) [Because it doesn't give the value of μ (Population mean)]
#
# x̄(New),
# x̄(Old)
#
# σ = 2.5
#
# n = 30
# *FORMULA*
#
# Z(test) = x̄(New) - x̄(Old)/ (σ/√n)

# %%
old_design_data = np.array([45.2, 42.8, 38.9, 43.5, 41.0, 44.6, 40.5, 42.7, 39.8, 41.4, 44.3,39.7, 42.1, 40.6, 43.0, 42.2,41.5, 39.6, 44.0, 43.1, 38.7, 43.9, 42.0, 41.9, 42.8, 43.7, 41.3, 40.9, 42.5, 41.6])
new_design_data = np.array([48.5, 49.1, 50.2, 47.8, 48.7, 49.9, 48.0, 50.5, 49.8, 49.6,48.2, 48.9, 49.7, 50.3, 49.4,50.1, 48.6, 48.3, 49.0, 50.0, 48.4, 49.3, 49.5, 48.8, 50.6, 50.4, 48.1, 49.2, 50.7,50.8])

# %%
pop_std = 2.5
n_sample = 30 #len(new_design_data) if we don't know length
alp = 0.05

# %%
mean_new = np.mean(new_design_data)
mean_old = np.mean(old_design_data)

# %%
mean_new, mean_old
# Out:
# (49.346666666666664, 41.99333333333333)

# %%
z_cal = (mean_new - mean_old) /(pop_std/np.sqrt(n_sample))

# %%
z_cal
# Out:
# 16.11034615808528

# %%
z_table = st.norm.ppf(1-alp)
z_table
# Out:
# 1.6448536269514722

# %%
if z_table < z_cal:
    print("H1 is right")
else:
    print("H0 is right")

#Hence new website is better than old.
# Out:
# H1 is right

# %% [markdown]
# **T-Test**
#
# *Hypotheses testing*(T-Test) :-
#
# Use when :-
#
# { Population data mean, sample data mean, sample data mean and STD, number of sample <30.
# }
#
# **FORMULA** :-
#
# T(test) = x̄ - μ / (σ/√n)
#
# *Where* :-
#
# x̄ = sample data mean
#
# μ = Population data mean
#
# σ = Standard division (sample data)
#
# n = no. of sample data
#
# _____________________
#
# **EXAMPLE 1:**
#
# A manufacturer claims that the average weight of a bag of potato chips is 150 grams. A sample of 25 bags is taken, and the average weight is found to be 148 grams, with a standard deviation of 5 grams. Test the manufacturer's claim using a one-tailed t-test with a significance level of 0.05.
#
# *Solve* :-
#
# μ (population data mean) = 150 grams
#
# x̄ (Sample data mean) = 148 grams
#
# σ (Standard deviation) = 5 grams
#
# n = 25
#
# α = 0.05
#
# Finding Null and alternative Hypothesis:-
#
# H0 -->> μ = 150 gram
#
# H1 -->> μ < 150 gram
#
# Find significant level with the help of α= 0.05
#
# Now we have to find T value in T table..
#
# Degree of freedom (Df)
#
# = n-1
#
# = 25-1
#
# = 24
#
#
#  Now  in code :-

# %%
import scipy.stats as st

# %%
t_table = st.t.ppf(0.05, 24) #First we put Alpha value then , Degree of data )
t_table
# Out:
# -1.7108820799094282

# %% [markdown]
# It return negative value it means we have left tail data

# %%
#Now we have to find T- Calculate
#Formula :- T(cal) = x̄ - μ /(σ/√n)
#T(Cal) = 148-150/(5/125)
#T(Cal) = -2

#It means H1 is true

# %% [markdown]
# **CHI SQUARE TEST**
#
# FORMULA :- (see copy)
#
# *EXAMPLE 1 :-*
#
# A fair die is rolled 120 times and the following results are obtained.
#
# Face 1: 22 times
#
# Face 2: 17 times
#
# Face 3: 20 times
#
# Face 4: 26 times
#
# Face 5: 22 times
#
# Face 6: 13 times
#
# Test at a 5% level of significance whether the die is fair.
#
# Solve :-
#
# Expected value = 20
#
# H0 -->> Die is fair
#
# H1 -->> Die is not fair
#
# [ Google search :- Chi Square Table -->> then see the value -->> Alpha value -->> DF value -->> find in table -->> chi square value is 11.07 ]
#
# Chi(cal) = sum ( O - E)²/E
#
# Now code ;-

# %%
import numpy as np

# %%
ob = np.array([22,17,20,26,22,13])
ex = np.array([20,20,20,20,20,20])

# %%
np.sum(np.square(ob-ex)/ex)
# Out:
# 5.1000000000000005

# %% [markdown]
# Chi Calculate value is 5.1 !! H0 is said that die is fair and H1 is said that die is fair ! Then we see that 11.07>5.so, H0 is right.
